# %% [markdown]
# # Convert videos into images

# %%
import cv2
import matplotlib.pyplot as plt
from mtcnn.mtcnn import MTCNN
import ffmpeg

# %%
#  def check_rotation(path_video_file):
#      # this returns meta-data of the video file in form of a dictionary
#      meta_dict = ffmpeg.probe(path_video_file)

#      # from the dictionary, meta_dict['streams'][0]['tags']['rotate'] is the key
#      # we are looking for
#      rotateCode = None
#      if int(meta_dict['streams'][0]['tags']['rotate']) == 90:
#          rotateCode = cv2.ROTATE_90_CLOCKWISE
#      elif int(meta_dict['streams'][0]['tags']['rotate']) == 180:
#          rotateCode = cv2.ROTATE_180
#      elif int(meta_dict['streams'][0]['tags']['rotate']) == 270:
#          rotateCode = cv2.ROTATE_90_COUNTERCLOCKWISE

#      return rotateCode

# %%
# Read video
sample_vid_path = '../data/raw/videos/eric_lee.mp4'
# rotateCode = check_rotation(sample_vid_path)
vidcap = cv2.VideoCapture(sample_vid_path)
success, image = vidcap.read()
image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE) 
count = 0

# %%
success, image = vidcap.read()
print(success)
if success:
    print("Reading successful")
    image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE) 
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# True
# Reading successful

# %%
image.shape
# Out:
# (1920, 1080, 3)

# %%
plt.imshow(cv2.cvtColor(image[250:1500,:,:], cv2.COLOR_BGR2RGB))

# %%
# Read video
sample_vid_path = '../data/raw/videos/eric_kwok.mp4'
vidcap = cv2.VideoCapture(sample_vid_path)
success, image = vidcap.read()
count = 0

# %%
success, image = vidcap.read()
print(success)
if success:
    print("Reading successful")
    image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE) 
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# True
# Reading successful

# %%
# Read video
sample_vid_path = '../data/raw/videos/clarence.mov'
vidcap = cv2.VideoCapture(sample_vid_path)
success, image = vidcap.read()
count = 0

# %%
success, image = vidcap.read()
print(success)
if success:
    print("Reading successful")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# True
# Reading successful

# %%
plt.imshow(cv2.cvtColor(image[:600,350:900,:], cv2.COLOR_BGR2RGB))

# %%
image.shape
# Out:
# (720, 1280, 3)
